# %% [markdown]
# # **`Exploratory Data Analysis Using Matplotlib & Seaborn`**
# # **`Data Aggregation, Grouping, Reshaping & Analysis`**

# %% [markdown]
# Author : Ashish Rogannagari
#
# 125127793+AshishRogannagari@users.noreply.github.com.

# %% [markdown]
# ![py.PNG](data:image/png;base64,...)

# %% [markdown]
# # <center><u>Introduction</u></center>

# %% [markdown]
# Importing the required libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# We load our required dataset into the Python environment using the following code.

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/AshishRogannagari/Data-Aggregation-Grouping-Reshaping-Analysis/main/Dataset/Customer_Segmentation.csv", encoding= 'unicode_escape')

# %%
# Import the Introduction module from src package
from src import Introduction as DataIntroduction

# %%
# Create an instance of the DataIntroduction class and pass the dataframe as an argument.
DataIntro = DataIntroduction.DataIntro(df)

# Call the Data_Details method to display information about the data.

DataIntro.Data_Details()
# Out:
# The dataset provided contains information about customers and their purchasing behavior.
#             .The fields include User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount, Status, and an unnamed column.
#             .The data seems to capture diverse demographic and transactional details, offering an opportunity for valuable insights into customer preferences and market trends.
#             .Upon initial analysis, several interesting patterns emerge.
#             .The dataset encompasses a range of ages, from minors (0-17 years old) to seniors (55+ years old).
#             .The majority falls within the 26-35 age group, suggesting a broad customer base.
#             .The gender distribution is fairly balanced, with male and female customers both actively participating in transactions.

# %% [markdown]
# This is a Data set of Customer segmentation based on the sales. Which contains all the details of customer purchased during the sale.
# This Data also provides
#
# Demographic Insights:
#
# The dataset encompasses a diverse demographic spectrum, including customers across various age groups and genders. This diversity allows for a nuanced analysis of consumer behavior, offering insights into how different segments interact with products and services. Understanding the age distribution can aid in tailoring marketing strategies to specific age groups, while gender analysis can unveil potential gender-specific preferences.
#
# Geographical Distribution:
# Geographic details such as the State and Zone provide a geographical context to the sales data. Analyzing sales across different regions can uncover regional preferences and potentially inform targeted regional marketing campaigns. The concentration of sales in specific states or zones may also hint at regional economic disparities or unique market conditions.
#
# Occupational Insights:
# The dataset delves into the occupational landscape of customers, revealing the sectors in which they are employed. This information is crucial for businesses aiming to align their products or services with the needs and interests of professionals in specific industries. Tailoring marketing efforts based on occupation can enhance engagement and customer satisfaction.
#
# Product Categories and Sales Trends:
# The Product_Category column unveils the variety of products being sold. Analyzing sales trends within different product categories can help businesses optimize inventory, identify high-demand items, and streamline product offerings. Additionally, tracking the evolution of sales over time could reveal seasonal trends or the impact of marketing initiatives.
#
# Order and Amount Analysis:
# The Orders and Amount columns offer a quantitative perspective on customer transactions. Examining the distribution of order quantities and corresponding amounts spent can unveil patterns in customer behavior. Businesses can leverage this information to identify customer segments with high purchasing power and tailor promotions or loyalty programs accordingly.
#
# Data Quality Considerations:
# The dataset appears to contain some missing or unspecified values, particularly in the Status and unnamed1 columns. Addressing these gaps is crucial for ensuring the accuracy of any subsequent analysis or modeling efforts.
#
# In essence, this sales dataset is a valuable resource for businesses seeking to optimize their strategies, enhance customer satisfaction, and stay attuned to the ever-evolving landscape of consumer preferences and market dynamics. Further exploration and analysis of this data hold the key to unlocking actionable insights that can drive informed decision-making.
#
# The Dataset can be available [link](https://www.analyticsvidhya.com/?s=Datasets).

# %% [markdown]
# # <center><u>DataSummary</u></center>

# %% [markdown]
# Let's break down the columns to understand the data:
#
# User_ID: Unique identifier for each user.
# Cust_name: Customer name.
# Product_ID: Identifier for each product.
# Gender: Gender of the customer (M or F).
# Age Group: Age group of the customer (e.g., 26-35).
# Age: Age of the customer.
# Marital_Status: Marital status of the customer (0 for unmarried, 1 for married).
# State: State where the customer is located.
# Zone: Geographical zone of the state.
# Occupation: Occupation of the customer.
# Product_Category: Category of the product.
# Orders: Number of orders placed.
# Amount: Amount spent on the product.
# unnamed13: An unnamed column without a clear description.
# Unnamed14: An unnamed column without a clear description.
#
# The Data summary of the it has 11251 rows and 15 columns in the data.
#
# Now, based on this information, you can perform various types of analysis depending on your project goals.

# %% [markdown]
# Descriptive Statistics:
#
# Calculate summary statistics for numerical columns (mean, median, standard deviation, etc.).
# Explore the distribution of categorical variables.
#
# Customer Demographics:
#
# Analyze the distribution of customers by gender, age group, marital status, state, and occupation.
#
# Product Analysis:
#
# Identify popular products based on the number of orders or total amount spent.
# Analyze the distribution of products across different categories.
#
# Order Analysis:
#
# Explore patterns in the number of orders and the total amount spent.
# Investigate the status of orders to identify any trends or issues.
#
# Geographical Analysis:
#
# Examine the distribution of customers across different states and zones.
#
# Correlation Analysis:
#
# Investigate potential correlations between variables (e.g., age and amount spent).
#
# Data Cleaning:
#
# Check for missing values in the dataset and handle them appropriately.
# Remove or address any duplicate records.

# %%
# Import the DataSummary module from src package.

from src import DataSummary as Datasum

# Create an instance of the DataSummary class and pass the dataframe as an argument.

Summary = Datasum.DataSummary(df)

# %%
# Create an instance of the DataSummary class and pass the dataframe as an argument.
Summary = Datasum.DataSummary(df)

# %% [markdown]
# To check what’s inside our loaded dataset:

# %%
# Display the summary of the dataset.
Summary.show()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# Checking the Dataset using the show fun it has 2 unamed columns.

# %%
# The code below calls the `shape()` method of the `Summary` object.
# This method returns the shape of the dataframe, which is the number of rows and columns.
Summary.shape()
# Out:
# (11251, 15)

# %% [markdown]
# The Data has 11251 rows and 15 columns

# %%
# Call the checkNull() method of the Summary object to check for null values in the dataset.
Summary.checkNull()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                  0
# Unnamed: 13         11251
# Unnamed: 14         11251
# dtype: int64

# %% [markdown]
# Checking null fun we got 11251 null values in 14,15 col,now we have to remove it for Analysis

# %%
# Call the `dataTypes()` method of the `Summary` object to check the data types of columns in the dataset.
Summary.dataTypes()
# Out:
# Data Types for Each Attribute:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# Unnamed: 13         float64
# Unnamed: 14         float64
# dtype: object

# %% [markdown]
# Checking the Datatypes of colums by using datatype fun

# %%
# Call the printColumns() method of the Summary object to print the columns of the dataset.
Summary.printColumns()
# Out:
# Column Names:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
# Call the removeColumn() method of the Summary object to remove the specified columns from the dataset.
Summary.removeColumn()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# Removed Two columns 14,15 which has null values.

# %%
# Call the printColumns() method of the Summary object to print the columns of the dataset.
Summary.printColumns()
# Out:
# Column Names:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Call the checkNull() method of the Summary object to check for null values in the dataset.
Summary.checkNull()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# Now we don't have any null values

# %%
# Call the show() method of the Summary object to display the summary of the dataset.
Summary.show()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# # <center><u>Exploratory Data Analysis</u></center>

# %%
# Import the EdaVisualizer class from the Eda module in the src package.

from src import Eda as edaans

# Create an instance of the EdaVisualizer class and pass the dataframe as an argument.

EdaAnalysis = edaans.EdaVisualizer(df)

# %% [markdown]
#  1:
# What is the distribution of ages in the dataset, and how are the ages spread across different age ranges?
#
# 2: What are the top 10 states with the highest number of customers, and how do these states compare in terms of customer count?
#
# 3:What are the top 10 products in terms of the amount spent, and how do these products compare based on the total amount spent?
#
# 4:How is the amount spent distributed across the dataset, and what insights can be gained from the distribution of spending?
#
# 5.Which product categories stand out as the most prominent in the dataset, and how do these categories contribute to the overall composition of products in the dataset?

# %%
# Plot the age distribution using Matplotlib.

EdaAnalysis.plotAgeDistributionMatplotlib()

# %%
# Plot the age distribution using Seaborn.

EdaAnalysis.plotAgeDistributionSeaborn()

# %% [markdown]
# Observation :1
#
# The dataset likely has a column named "Age"  has numerical values representing the ages of individuals.
# The graphs illustrates the frequency of individuals across different age ranges.
# The x-axis shows the age values and the y-axis shows the frequency.
#
#
# `From the above graph we can see that the Age group of 18-55 are spending.`

# %%
# Plot the top states with the highest number of customers using Matplotlib.

EdaAnalysis.plotTopStatesCustomersMatplotlib()

# %%
# Plot the top states with the highest number of customers using Seaborn.

EdaAnalysis.plotTopStatesCustomersSeaborn()

# %% [markdown]
# Observation :2
#
# The dataset likely has a column named "State"  has names representing the  of individual of states.
# The graphs illustrates the Number of customers
# The x-axis shows the state Names and the y-axis shows the No.of customers across the state.
#
#
# `From the above graph we can see that the Top 10 states by Number of Customers are shopping.`

# %%
# Plot the top products with the highest sales using Matplotlib.

EdaAnalysis.highestSalesForProductsMatplotlib()

# %%
# Plot the top products with the highest sales using Seaborn.

EdaAnalysis.highestSalesForProductsSeaborn()

# %% [markdown]
# Observation :3
#
# The dataset likely has a column named "Product_Category"  has names representing the Category of each product.
# The graphs illustrates the Amount spent by Number of customers.
# The x-axis shows the Amount spent by customers and the y-axis shows the product category of the products.
#
#
# `From the above graph we can see that what are the Top 10 products of shopping according to their category.`

# %%
# Plot the amount spent using Matplotlib

EdaAnalysis.plotAmountSpentMatplotlib()

# %%
# Plot the amount spent using Seaborn.

EdaAnalysis.plotAmountSpentSeaborn()

# %% [markdown]
# Observation :4
#
# The dataset likely has a column named "Amount"  has names representing the  of Amount Spent.
# The graphs illustrates the Distribution of Amount spend.
# The x-axis shows the state Amount and the y-axis shows the Frequeny of total amount.
#
#
# `From the above graph we can see that the Amount spending from 3000-25000 on shopping and the highest amount range approx. 24000.`

# %%
# Generate a word cloud of the product categories using the EdaAnalysis object.

EdaAnalysis.generateProductsWordCloud()

# %% [markdown]
# Observation :5
#
# The dataset likely has a column named "Product_Category"  has names representing the  of Category of items according to Data.
# The graphs illustrates the Product Category.
#
#
# `From the above graph we can see that Larger words represent product categories that occur more frequently.`

# %% [markdown]
# # <center><u>Inference </u></center>

# %% [markdown]
# Here are some Research Questions for the Data. We Can Find

# %% [markdown]
# 1.Is there a relationship between customer age group and amount spent on products? This could analyze spending patterns across different age groups?
#
# 2.Do married customers spend more on products than unmarried customers? This would analyze if marital status impacts spending?
#
# 3.Is there a difference in product spending between males and females? This would look at gender differences in spending?
#
# 4.Do certain occupations spend more on products than others? This would explore if occupation is related to product spending?
#
# 5.Is the amount spent on products associated with the customer's state or zone? This would analyze geographical differences in spending?
#
# 6.Are there differences in product spending across product categories? This explores if certain product categories garner more customer spending than others?
#
# 7.Does the number of orders placed by a customer predict the total amount they will spend? This would assess if frequency of orders impacts overall spend?
#
# 8.Do older customers (55+ age group) spend more or less than younger customers? This specifically looks at differences between younger and older consumers?

# %%
# Import the Inference class from the Inference module in the src package.

from src import Inference as ins

# Create an instance of the Inference class and pass the dataframe as an argument.

Interferences = ins.DatasetEDA(df)

# %% [markdown]
# Finding the Summary off the Data set,It Gives the mean ,med, std, min amount of the order and max amount of the order and more.

# %%
# Call the displaySummary() method of the Interferences object to display the summary of the dataset.

Interferences.displaySummary()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9466.307656
# std    1.716125e+03     12.754122        0.493632      1.115047   5234.014519
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8110.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12691.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# Call the plotAmountByAgeGroup() method of the Interferences object to plot the amount spent by age group.

Interferences.plotAmountByAgeGroup()

# %% [markdown]
# Observation 1:
#
# Relationship between customer age group and amount spent on products:
# The Graph is a box plot using the Seaborn library to illustrate the relationship between customer age groups and the amount spent on products.and how spending varies across different age groups in the dataset
#
# Each box in the plot represents the distribution of spending within a specific age group.
#
# The x-axis displays different age groups, and the y-axis shows the corresponding amounts spent.
#
# `The Age group 26-35 and 51-55 are spending more comparing to other age groups.`

# %%
# Call the plotAmountByMaritalStatus() method of the Interferences object to plot the amount spent by marital status.

Interferences.plotAmountByMaritalStatus()

# %% [markdown]
# Observation 2:
#
# Impact of marital status on customer spending:
#
# The Graph is a FacetGrid using Seaborn to visualize the distribution of product amounts based on marital status.
# and `0` stands for `Unmarried` and `1` stands for `Married.`
#
# And it organized into separate columns for each marital status, and each column contains a histogram representing the distribution of amounts spent.
#
# It provides insights into how product spending varies among different marital statuses in the dataset.
#
# The x-axis displays different Amount, and the y-axis shows the Density of range.
#
# `The Unmarried are spending more on shopping compared to married.`

# %%
# Call the plotAmountByGender() method of the Interferences object to plot the amount spent by gender.

Interferences.plotAmountByGender()

# %% [markdown]
# Observation 3:
#
# Gender differences in product spending:
#
# The Graph is aviolin plot using Seaborn to compare product spending between males and females.
#
# and `F` stands for `Female` and `M` stands for `Male.`
#
# It provides insights  of spending patterns, including quartiles and probability density.
#
# The x-axis represents Gender, and the y-axis shows the distribution of Amounts spent.
#
# `The Females are spending more on shopping compared to Male, The Highest Order Amount is 23952/-`

# %%
# Call the plotAmountByOccupation() method of the Interferences object to plot the amount spent by occupation.

Interferences.plotAmountByOccupation()

# %% [markdown]
# Observation 4:
#
# Relationship between occupation and product spending:
#
# The Graph is  bar chart using Seaborn to illustrate the average amount spent by different occupations.
#
# It provides insights and  quick comparison of average spending across different occupations, highlighting the occupation with the highest average amount spent.
#
# The x-axis represents Occupation, and the y-axis shows the Average of Amounts spent on orders.
#
# `The Females are spending more on shopping compared to Male, The Average Amount is 9973 and their Occupation is "Govt"`

# %%
# Call the plotAmountByState() method of the Interferences object to plot the amount spent by state.

Interferences.plotAmountByState()

# %% [markdown]
# Observation 5:
#
# Geographical differences in product spending:
#
# The Graph is a horizontal bar chart using Seaborn to illustrate the average amount spent in different states or zones.
#
# It provides a quick comparison of average spending across different states or zones, providing insights into regional spending patterns.
#
# The x-axis represents Avg of Amount spent, and the y-axis shows the states spent on orders.
#
# `The Females are From Delhi, Karnataka, Uttar Pradesh and Andhra Pradesh are spend more amount comparing to all other states`

# %%
# Call the plotAmountByProductCategory() method of the Interferences object to plot the amount spent by product category.

Interferences.plotAmountByProductCategory()

# %% [markdown]
# Observation 6:
#
#  Product spending across different categories:
#
# The Graph is  a bar chart using Seaborn to illustrate the average amount spent on different product categories..
#
# It provides a quick comparison of average spending across different product categories, providing insights into which categories attract higher or lower spending.
#
# The x-axis represents Product Category, and the y-axis shows the Average of Amount spent on orders.
#
# `They are spending more on the Auto and Tupperware Category`

# %%
# Call the plotAmountVsOrders() method of the Interferences object to plot the amount spent vs. the number of orders.

Interferences.plotAmountVsOrders()

# %% [markdown]
# Observation 7:
#
# Relationship between number of orders and total spending:
#
# The Graph is a joint plot to visualize the relationship between the number of orders placed by customers and the total amount they spent.
#
# The x-axis represents the number of orders, the y-axis represents the amount spent, and each point on the plot corresponds to a customer's data.
#
# The plot includes a regression line that indicates the overall trend between the two variables.
#
# `Providing insights into how customer spending correlates with the frequency of orders placed.`

# %%
# Call the plotAmountByAgeAndGender() method of the Interferences object to plot the amount spent by age and gender.

Interferences.plotAmountByAgeAndGender()

# %% [markdown]
# Observation 8:
#
# Comparison of spending between younger and older customers:
#
# The Graph is a bar chart using Seaborn to visualize the average amount spent by customers across different age groups and genders.
#
# Each bar represents an age group, and the bars are color-coded to distinguish between different genders.
#
# The height of the bars corresponds to the average amount spent.
#
# The x-axis represents Age-group, and the y-axis shows the states spent on orders.
#
# Allowing insights into how average spending varies among different age groups and genders
#
# `The Average Amount spend by gender is Male is Highest and their age agroup is 51-55.`

# %% [markdown]
# ## `Conclusion:`

# %% [markdown]
# ##### Age Group Influence:
#
# The age groups 26-35 and 51-55 demonstrate higher spending compared to other age groups.
#
# ##### Marital Status Impact:
#
# Unmarried individuals tend to spend more on shopping compared to their married counterparts.
#
# ##### Gender Disparity:
#
# Females, particularly those with a government occupation, are observed to spend more on shopping than males.
# The highest individual order amount recorded is substantial, reaching 23952 for females.
#
# ##### Regional Spending Variations:
#
# Females residing in Delhi, Karnataka, Uttar Pradesh, and Andhra Pradesh exhibit higher spending compared to those in other states.
#
# ##### Category Preferences:
#
# There is a noticeable inclination towards spending more on the Auto and Tupperware categories.
#
# ##### Order Frequency and Spending Correlation:
#
# Further insights into customer spending habits can be gained by examining the correlation between spending and the frequency of orders placed.
#
# ##### Average Spending and Demographics:
#
# The average spending amount for males are highest, particularly among the age group 51-55.

# %% [markdown]
# ### `References:`

# %% [markdown]
# The Dataset can be available [link](https://raw.githubusercontent.com/AshishRogannagari/Data-Aggregation-Grouping-Reshaping-Analysis/main/Dataset/Customer_Segmentation.csv).
#
# https://realpython.com/python-matplotlib-guide/
#
# https://realpython.com/python-seaborn-guide/
#
# https://www.datacamp.com/tutorial/wordcloud-python
#
# https://pandas.pydata.org/pandas-docs/stable/
#
# http://scikit-learn.org/stable/index.html
#
# https://www.tensorflow.org/api_guides/python/basics
#
# https://keras.io/layers/core_layers/dot
#
#
# https://towardsdatascience.com/how-to-create-a-beautiful-interactive-dashboard-with
#
# http://blog.yhathq.com/posts/coloring-words-with-tweets.html
#
# https://medium.com/
#
# https://towardsdatascience.com/10-ways-to-visualize-your-data-in-python-3
#
# https://towardsdatascience.com/how-to-use-the-pandas-library-for-dataframe-manip
#
# https://towardsdatascience.com/5-essential-tools-every-data-scientist-should-know-

# %% [markdown]
# # <center><u>`Thank You` </u></center>
